# %% [markdown]
# https://www.kaggle.com/competitions/titanic/data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic_kaggle.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
sns.countplot(x='Embarked', data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(x='Survived', data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived', data=df, hue='Pclass')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# fetch the rows for which Embarked is NaN

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# fetch the passengers who survived in pclass 3

# %%
df.query("Pclass == 3 and Survived == 1")
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# ..           ...       ...     ...
# 838          839         1       3
# 855          856         1       3
# 858          859         1       3
# 869          870         1       3
# 875          876         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# fetch the passengers who are travelling with either their Spouse/Sibling OR parents/children

# %%
df[(df['Parch']>0) | (df['SibSp']>0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.query("SibSp > 0 or Parch > 0")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# fetch all the passengers who paid the fare more than the mean value of the fare

# %%
df[df['Fare'] > df['Fare'].mean()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
sns.displot(x='Fare', data=df)

# %%
sns.displot(x='Fare', data=df, bins=20)

# %%
df[df['Fare']>200]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 527          528         0       1
# 557          558         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %%
len(df[df['Fare']>200])
# Out:
# 20

# %%
df[df['Fare']>500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df[df['Fare']>500].index
# Out:
# Int64Index([258, 679, 737], dtype='int64')

# %%
df.drop(df[df['Fare']>500].index)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1 = df.drop(df[df['Fare']>500].index)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.displot(x='Fare', data=df1, bins=20)

# %%
sns.displot(x='Age', data=df)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Handling missing data

# %%
# Age - fill it with mean/media
# Cabin - fill it with 'NA' OR delete the column?
# Embarked - delete the missing rows OR fill it with mode?

# %%
df1['Age'].mean()
# Out:
# 29.67534458509142

# %%
df1['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df1['Embarked'].mode().loc[0]
# Out:
# 'S'

# %%
df2 = df1.drop(['Cabin'], axis=1)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.fillna({'Age': df2['Age'].mean(), 'Embarked': df2['Embarked'].mode().loc[0]}, inplace=True)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
sns.displot(x='Age', data=df2)

# %%
sns.displot(x='Age', data=df)

# %%
sns.displot(x='Age', data=df2, bins=8)

# %%
sns.displot(x='Age', data=df, bins=8)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# get_dummies

# %%
pd.get_dummies('Sex')
# Out:
#    Sex
# 0    1

# %%
help(pd.get_dummies)
# Out:
# Help on function get_dummies in module pandas.core.reshape.encoding:
#
# get_dummies(data, prefix=None, prefix_sep='_', dummy_na: 'bool' = False, columns=None, sparse: 'bool' = False, drop_first: 'bool' = False, dtype: 'Dtype | None' = None) -> 'DataFrame'
#     Convert categorical variable into dummy/indicator variables.
#
#     Parameters
#     ----------
#     data : array-like, Series, or DataFrame
#         Data of which to get dummy indicators.
#     prefix : str, list of str, or dict of str, default None
#         String to append DataFrame column names.
#         Pass a list with length equal to the number of columns
#         when calling get_dummies on a DataFrame. Alternatively, `prefix`
#         can be a dictionary mapping column names to prefixes.
#     prefix_sep : str, default '_'
#         If appending prefix, separator/delimiter to use. Or pass a
#         list or dictionary as with `prefix`.
#     dummy_na : bool, default False
# ...

# %%
gender_dummies = pd.get_dummies(df2['Sex'])

# %%
gender_dummies
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [888 rows x 2 columns]

# %%
embarked_dummies = pd.get_dummies(df2['Embarked'])

# %%
embarked_dummies
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [888 rows x 3 columns]

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df3 = pd.concat([df2, gender_dummies, embarked_dummies], axis=1)

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df3.drop(['Name', 'Sex', 'Ticket', 'Embarked'], axis=1, inplace=True)

# %%
df3
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare  female  \
# 0              1         0       3  22.000000      1      0   7.2500       0
# 1              2         1       1  38.000000      1      0  71.2833       1
# 2              3         1       3  26.000000      0      0   7.9250       1
# 3              4         1       1  35.000000      1      0  53.1000       1
# 4              5         0       3  35.000000      0      0   8.0500       0
# ..           ...       ...     ...        ...    ...    ...      ...     ...
# 886          887         0       2  27.000000      0      0  13.0000       0
# 887          888         1       1  19.000000      0      0  30.0000       1
# 888          889         0       3  29.675345      1      2  23.4500       1
# 889          890         1       1  26.000000      0      0  30.0000       0
# 890          891         0       3  32.000000      0      0   7.7500       0
#
#      male  C  Q  S
# 0       1  0  0  1
# ...

# %%
# Coorelation and Heatmap

# coorelation means relation between two columns or two data, calculated only on numerical columns

# %%
df3
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare  female  \
# 0              1         0       3  22.000000      1      0   7.2500       0
# 1              2         1       1  38.000000      1      0  71.2833       1
# 2              3         1       3  26.000000      0      0   7.9250       1
# 3              4         1       1  35.000000      1      0  53.1000       1
# 4              5         0       3  35.000000      0      0   8.0500       0
# ..           ...       ...     ...        ...    ...    ...      ...     ...
# 886          887         0       2  27.000000      0      0  13.0000       0
# 887          888         1       1  19.000000      0      0  30.0000       1
# 888          889         0       3  29.675345      1      2  23.4500       1
# 889          890         1       1  26.000000      0      0  30.0000       0
# 890          891         0       3  32.000000      0      0   7.7500       0
#
#      male  C  Q  S
# 0       1  0  0  1
# ...

# %%
df3.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.006916 -0.033005  0.032595 -0.056929 -0.002223
# Survived       -0.006916  1.000000 -0.334068 -0.071817 -0.033395  0.082157
# Pclass         -0.033005 -0.334068  1.000000 -0.330647  0.080937  0.018212
# Age             0.032595 -0.071817 -0.330647  1.000000 -0.232105 -0.179246
# SibSp          -0.056929 -0.033395  0.080937 -0.232105  1.000000  0.415141
# Parch          -0.002223  0.082157  0.018212 -0.179246  0.415141  1.000000
# Fare           -0.002046  0.261742 -0.604960  0.093679  0.211816  0.263910
# female         -0.040265  0.545899 -0.132881 -0.084160  0.114799  0.247003
# male            0.040265 -0.545899  0.132881  0.084160 -0.114799 -0.247003
# C              -0.004322  0.160969 -0.234999  0.029181 -0.056637 -0.010733
# Q              -0.033204  0.004981  0.220331 -0.013657 -0.026861 -0.081351
# ...

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df2.corr()

# coorelation values between two rows and two clumns always between -1 and plus 1
# ifthe coorelation between two columns are close to plus one thatmeans they are highly coorelated/ directly proportional
# ex:- if there are two columns x and y 
# if the coorelation between x and y is 0.5 then if xincreases then y increases by 0.5
# ex 2:- if the coorelation between x andy is -0.7 it means if youincrease 10 by factor 10 then y decrease by 7
# inverely proportional with the factor minus

# in the below dataframe the relation between fare and survival is 0.26 means as the fair increases the survival increases by 26%
# the coorelation between pcclass and survival is -0.33 that means if pcclass increases then survival decreases
# tht means pc class is 3, 2, 1 -> 1st class, 2nd class, 3rd class(that means numerically it is high but it is lower class)
# therefore the pc class increases survival rate decreases
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1616\1778878097.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.006916 -0.033005  0.032595 -0.056929 -0.002223
# Survived       -0.006916  1.000000 -0.334068 -0.071817 -0.033395  0.082157
# Pclass         -0.033005 -0.334068  1.000000 -0.330647  0.080937  0.018212
# Age             0.032595 -0.071817 -0.330647  1.000000 -0.232105 -0.179246
# SibSp          -0.056929 -0.033395  0.080937 -0.232105  1.000000  0.415141
# Parch          -0.002223  0.082157  0.018212 -0.179246  0.415141  1.000000
# Fare           -0.002046  0.261742 -0.604960  0.093679  0.211816  0.263910
#
#                  Fare
# PassengerId -0.002046
# Survived     0.261742
# ...

# %%
sns.heatmap(df2.corr())
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1616\325437066.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr())
# <Axes: >

# %%
sns.heatmap(df2.corr(), annot=True, cmap='coolwarm')

# here annot = True is used to get the values on the graph and cmap = 'coolwarm' is used to change the colours
# here if it closely related to plus 1 then it is closely related,if it is related to -1 then it is inversely related 
# and if it is closely related to 0 then it is not related to anyone

# any matrix like coorelated can be plotted we can plot other types of matrix also covered later
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1616\3336253389.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(), annot=True, cmap='coolwarm')
# <Axes: >

# %%
help(sns.heatmap)
# Out:
# Help on function heatmap in module seaborn.matrix:
#
# heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)
#     Plot rectangular data as a color-encoded matrix.
#
#     This is an Axes-level function and will draw the heatmap into the
#     currently-active Axes if none is provided to the ``ax`` argument.  Part of
#     this Axes space will be taken and used to plot a colormap, unless ``cbar``
#     is False or a separate Axes is provided to ``cbar_ax``.
#
#     Parameters
#     ----------
#     data : rectangular dataset
#         2D dataset that can be coerced into an ndarray. If a Pandas DataFrame
#         is provided, the index/column information will be used to label the
#         columns and rows.
#     vmin, vmax : floats, optional
# ...
